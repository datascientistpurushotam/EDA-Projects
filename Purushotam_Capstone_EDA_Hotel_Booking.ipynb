# %% [markdown]
# <a href="https://colab.research.google.com/github/datascientistpurushotam/EDA-Projects/blob/Hotel_Booking_Analysis/Purushotam_Capstone_EDA_Hotel_Booking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Capstone project for EDA "Hotel Booking".**

# %% [markdown]
# ![Capture11.PNG](data:image/png;base64,...)

# %% [markdown]
# # Git Hub Link
#
# https://github.com/datascientistpurushotam/EDA-Projects/tree/Hotel_Booking_Analysis

# %% [markdown]
# **importing modules**

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# **Loading dataset**

# %%
hoteldata = pd.read_csv('/content/Hotel Bookings raw.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (24) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # **Getting info**

# %%
hoteldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58890 entries, 0 to 58889
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           58890 non-null  object
#  1   is_canceled                     58890 non-null  int64
#  2   lead_time                       58890 non-null  int64
#  3   arrival_date_year               58890 non-null  int64
#  4   arrival_date_month              58890 non-null  object
#  5   arrival_date_week_number        58890 non-null  int64
#  6   arrival_date_day_of_month       58890 non-null  int64
#  7   stays_in_weekend_nights         58890 non-null  int64
#  8   stays_in_week_nights            58890 non-null  int64
#  9   adults                          58890 non-null  int64
#  10  children                        58886 non-null  float64
#  11  babies                          58890 non-null  int64
# ...

# %% [markdown]
# **Data Description:**
# **hotel** : Hotel(Resort Hotel or City Hotel)
#
# **is_canceled** : Value indicating if the booking was canceled (1) or not (0)
#
# **lead_time **bold text** **:* Number of days that elapsed between the entering date of the booking into the PMS and the arrival date*
#
# **arrival_date_year** : Year of arrival date
#
# **arrival_date_month** : Month of arrival date
#
# **arrival_date_week_number** : Week number of year for arrival date
#
# **arrival_date_day_of_month** : Day of arrival date
#
# **stays_in_weekend_nights** : Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
#
# **stays_in_week_nights** : Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
#
# **adults **bold text** **: Number of adults
#
# **children** : Number of children
#
# **babies** : Number of babies
#
# **meal** : Type of meal booked. Categories are presented in standard hospitality meal packages:
#
# **country** : Country of origin.`
#
# **market_segment** : Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# **distribution_channel**  : Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# **is_repeated_guest** : Value indicating if the booking name was from a repeated guest (1) or not (0)
#
# **previous_cancellations** : Number of previous bookings that were cancelled by the customer prior to the current booking
#
# **previous_bookings_not_canceled **: Number of previous bookings not cancelled by the customer prior to the current booking
#
# **reserved_room_type** : Code of room type reserved. Code is presented instead of designation for anonymity reasons.
#
# **assigned_room_type** : Code for the type of room assigned to the booking.
#
# **booking_changes** : Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
#
# **deposit_type** : Indication on if the customer made a deposit to guarantee the booking.
#
# **agent **: ID of the travel agency that made the booking
#
# **company **: ID of the company/entity that made the booking or responsible for paying the booking.
#
# **days_in_waiting_list** : Number of days the booking was in the waiting list before it was confirmed to the customer
#
# **customer_type** : Type of booking, assuming one of four categories
#
# **adr **: Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights
#
# **required_car_parking_spaces** : Number of car parking spaces required by the customer
#
# **total_of_special_requests** :* Number of special requests made by the customer (e.g. twin bed or high floor)*
#
# **reservation_status** : Reservation last status, assuming one of three categories
#
# **Canceled** – booking was canceled by the customer
# Check-Out – customer has checked in but already departed
# No-Show – customer did not check-in and did inform the hotel of the reason why
# reservation_status_date : Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel

# %% [markdown]
# **Gettiing Description**

# %%
hoteldata.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  58890.000000  58890.000000       58890.000000
# mean       0.411360    100.046714        2015.974597
# std        0.492084    101.157752           0.687274
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     17.000000        2016.000000
# 50%        0.000000     69.000000        2016.000000
# 75%        1.000000    157.000000        2016.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              58890.000000               58890.000000
# mean                  27.837426                  15.767159
# std                   13.346370                   8.783033
# min                    1.000000                   1.000000
# 25%                   17.000000                   8.000000
# 50%                   29.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %% [markdown]
# **Removing dublicates**

# %%
hoteldata.drop_duplicates(inplace=True)
hoteldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44203 entries, 0 to 58889
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           44203 non-null  object
#  1   is_canceled                     44203 non-null  int64
#  2   lead_time                       44203 non-null  int64
#  3   arrival_date_year               44203 non-null  int64
#  4   arrival_date_month              44203 non-null  object
#  5   arrival_date_week_number        44203 non-null  int64
#  6   arrival_date_day_of_month       44203 non-null  int64
#  7   stays_in_weekend_nights         44203 non-null  int64
#  8   stays_in_week_nights            44203 non-null  int64
#  9   adults                          44203 non-null  int64
#  10  children                        44199 non-null  float64
#  11  babies                          44203 non-null  int64
# ...

# %% [markdown]
# **We found that  out of 119389, only 87396 are non dublicate rows**

# %% [markdown]
# **Getting net non na rows**

# %%
hoteldata.dropna()
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 2392   Resort Hotel            0          6               2015
# 2697   Resort Hotel            0         24               2015
# 2867   Resort Hotel            0         24               2015
# 2877   Resort Hotel            0         24               2015
# 2878   Resort Hotel            0         24               2015
# ...             ...          ...        ...                ...
# 41005    City Hotel            0          0               2015
# 41142    City Hotel            0          0               2015
# 42126    City Hotel            0          1               2015
# 43580    City Hotel            0         19               2015
# 46695    City Hotel            1          1               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2392             October                        42                         11
# ...

# %% [markdown]
# only 189 rows × 32 columns found completed so we cannot use this code here

# %% [markdown]
# As company column has only 5259 non-null   float64 value and we do not found data for our used so we decided remove this column

# %%
del hoteldata['company']

# %%
hoteldata.shape
# Out:
# (44203, 31)

# %%
def percentage(valuea,valueb):

  percent = valuea*100/(valuea + valueb)
  return percent

# %% [markdown]
# So  (87396, 31) hoteldata is now cleaned and we are ready to perform EDA on this dataset

# %% [markdown]
# # ` Question 1.`  Which customer type prefered the most city hotel.

# %%
city_hotel = hoteldata['customer_type'][hoteldata['hotel']=='City Hotel'].value_counts()
city_hotel.plot(kind='bar',figsize= (25,5))
display(city_hotel)
# Out:
# Transient          7609
# Transient-Party    1917
# Contract            678
# Group                30
# Name: customer_type, dtype: int64

# %% [markdown]
# From the above graph shows  that transient customer most prefered the city hotel.

# %% [markdown]
# # `Question 2.` Which type of hotel non refunded the most.

# %%
nondeposit_data = hoteldata['hotel'][hoteldata ['deposit_type']=='Non Refund'].value_counts()
display(nondeposit_data)
nondeposit_data.plot(kind = 'pie', figsize = (10,10) )
# Out:
# City Hotel      277
# Resort Hotel    193
# Name: hotel, dtype: int64

# %% [markdown]
# This graph shows that city hotel non refunded the most.

# %% [markdown]
# # `Question 3.` Which distribution channel is mostly used for booking Resort hotel.

# %%
booking_channel = hoteldata['distribution_channel'] [hoteldata['hotel']=='Resort Hotel'].value_counts()
display(booking_channel)
booking_channel.plot(kind = 'bar', figsize = (25,5))
# Out:
# TA/TO        24592
# Direct        6901
# Corporate     2474
# Undefined        1
# Name: distribution_channel, dtype: int64

# %% [markdown]
# This bar graph shows that **TA/TO** is most prefered for Resort Hotel

# %% [markdown]
# # `Question 4.` Which type of hotel is preferred by customer having babies.

# %%
babies_hotel = hoteldata[['hotel','babies']].value_counts()
display(babies_hotel)
babies_hotel.plot(kind = 'bar',figsize = (25,5),color = 'purple')
# Out:
# hotel         babies
# Resort Hotel  0         33423
# City Hotel    0         10174
# Resort Hotel  1           536
# City Hotel    1            60
# Resort Hotel  2             9
# City Hotel    10            1
# dtype: int64

# %% [markdown]
# From the above graph shows that City hotel is most preffered by the customer having  babies.

# %% [markdown]
# # `Question 5.` Which type of hotel is most preferred for week night?

# %%
week_night = hoteldata[['stays_in_week_nights','hotel']].value_counts()
display(week_night)
week_night.plot(kind='bar',color = 'skyblue', legend = True,figsize =(25,5))
# Out:
# stays_in_week_nights  hotel
# 1                     Resort Hotel    7720
# 5                     Resort Hotel    6773
# 2                     Resort Hotel    5953
# 3                     Resort Hotel    4690
# 2                     City Hotel      3028
# 4                     Resort Hotel    3010
# 1                     City Hotel      2541
# 0                     Resort Hotel    2378
# 3                     City Hotel      2174
# 6                     Resort Hotel    1020
# 4                     City Hotel      1007
# 10                    Resort Hotel     839
# 7                     Resort Hotel     774
# 5                     City Hotel       600
# 0                     City Hotel       585
# 8                     Resort Hotel     458
# 9                     Resort Hotel     150
# 6                     City Hotel        94
# 7                     City Hotel        55
# 15                    Resort Hotel      50
# 10                    City Hotel        42
# ...

# %% [markdown]
# This Graph shows that Resort hotel is most prefered for week nights.

# %% [markdown]
# # `Question 6.**` Which year has highest booking and cancellation based on market segment (Direct).

# %%
booking_segment = hoteldata['arrival_date_year'][hoteldata['market_segment']=='Direct'].value_counts()
print(booking_segment)
booking_segment.plot(kind = 'bar',color = 'purple',  figsize=(25,10))
# Out:
# 2016    5326
# 2017    4332
# 2015    2146
# Name: arrival_date_year, dtype: int64

# %% [markdown]
# This Graph shows that 2016 has highest booking and cancellation based on market segment (Direct).

# %% [markdown]
# # `Question 7.` Which food is most preferred by customer based on top 5 countries.

# %%
food_country = hoteldata[['meal','country']].value_counts().nlargest(5)
display(food_country)
food_country.plot(figsize = (25,5), color = 'purple',kind = 'bar')
# Out:
# meal  country
# BB    PRT        22283
#       GBR         7796
#       FRA         6769
#       ESP         5178
#       DEU         4059
# dtype: int64

# %% [markdown]
# The graph shows that Portugal preferred the BB food in top 5 countires.

# %% [markdown]
# # `Question 8.`Which month is  Most favourable for booking.

# %%
month_booking = hoteldata[['hotel','arrival_date_month']].value_counts().groupby('arrival_date_month').max().sort_values( ascending = False)
display(month_booking)
month_booking.plot(figsize = (25,5),kind = 'bar')
# Out:
# arrival_date_month
# August       6591
# July         5744
# May          5413
# April        5080
# June         5005
# March        4856
# September    4240
# October      4208
# February     3605
# December     3014
# November     2942
# January      2730
# dtype: int64

# %% [markdown]
# This Graph shows that August month is most favourable month for booking.

# %% [markdown]
# # `Question 9. `Which are the top five agents for Resort hotel?

# %%
agent_booking = hoteldata['agent'][hoteldata['hotel']=='Resort Hotel'].value_counts().nlargest(5)
display(agent_booking)
agent_booking.plot(kind = 'bar', color = 'purple',figsize = (25,5))
# Out:
# 240.0    13020
# 250.0     2778
# 241.0     1644
# 40.0       954
# 314.0      844
# Name: agent, dtype: int64

# %% [markdown]
# This Graph shows that 240.0 is the top agent for booking resort hotel.

# %% [markdown]
# # `Question 10.` Hotel data based on month where repeated guest is 0.

# %%
date_booking = hoteldata['arrival_date_month'][hoteldata['is_repeated_guest']==0].value_counts().nlargest(12).sort_values(ascending=False)
display(date_booking)
date_booking.plot(kind='bar',figsize= (25,8))
# Out:
# August       6445
# July         5219
# September    4259
# May          3595
# October      3559
# April        3559
# June         3273
# March        3259
# February     2764
# December     2237
# January      2213
# November     2114
# Name: arrival_date_month, dtype: int64

# %% [markdown]
# This graph shows that in the month of August no repeated guest.

# %% [markdown]
# # **Conclusions:**

# %% [markdown]
# 1-Transient customer most preferred the city hotel.
#
# 2-City Hotel not refunded the most 845 in cocmparison of resort hotel 193.
#
# 3-TA/TO is most preferred distribution channel for booking for resort hotels.
#
# 4- City hotel is most preferred by customers having babies as compared to resort hotel.
#
# 5-City Hotel is most preferred for week night as comapred to  resort hotel.
#
# 6- in the year 2016 has highest booking and cancellation based on market segment (Direct).
#
# 7-Portugal preferred the BB food in top 5 countires.
#
# 8-August month is most favourable month for booking.
#
# 9- 240.0 is the top agent for booking resort hotel.
#
# 10- August month has no repeated guest with 0.
#
# From the above conclusions we can say that City hotels are the most preferred hotel type by the guests. We can say City hotel is the busiest hotel.
